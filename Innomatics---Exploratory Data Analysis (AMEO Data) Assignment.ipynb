# %% [markdown]
# # Project - Exploratory Data Analysis (AMEO Data)
# #### Assignment By: Priyanka Tanpure

# %% [markdown]
# ### Intoduction
#
# The dataset was released by Aspiring Minds from the Aspiring Mind Employment Outcome 2015 (AMEO). The study is primarily limited  only to students with engineering disciplines. The dataset contains the employment outcomes of engineering graduates as dependent variables (Salary, Job Titles, and Job Locations) along with the standardized scores from three different areas – cognitive skills, technical skills and personality skills. The dataset also contains demographic features.
#
# The dataset  contains  around  40 independent variables and 4000 data points. The independent variables are both continuous and categorical in nature. The dataset contains a unique identifier for each candidate. Below mentioned table contains the details for the original dataset.

# %% [markdown]
# ### Problem Statement
#
# Times of India article dated Jan 18, 2019 states that “After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh graduate.” **Test this claim with the data given to you.**
#
# **Is there a relationship between gender and specialisation? (i.e. Does the preference of Specialisation depend on the Gender?)**

# %% [markdown]
# ### Dataset Information
#
# | VARIABLES | TYPE | Description |
# | :--- | :--- | ---: |
# | ID | UID | A unique ID to identify a candidate |
# | Salary | Continuous | Annual CTC oﬀered to the candidate (in INR) |
# | DOJ | Date | Date of joining the company |
# | DOL | Date | Date of leaving the company |
# | Designation | Categorical | Designation oﬀered in the job |
# | JobCity | Categorical | Location of the job (city) |
# | Gender | Categorical | Candidate’s gender |
# | DOB | Date | Date of birth of candidate |
# | 10percentage | Continuous | Overall marks obtained in grade 10 examinations |
# | 10board | Continuous | The school board whose curriculum the candidate followed in grade 10 |
# | 12graduation | Date | Year of graduation - senior year high school |
# | 12percentage | Continuous | Overall marks obtained in grade 12 examinations |
# | 12board | Date | The school board whose curriculum the candidate followed in grade 12 |
# | CollegeID | NA/ID | Unique ID identifying the college which the candidate attended |
# | CollegeTier | Categorical | Tier of college |
# | Degree | Categorical | Degree obtained/pursued by the candidate |
# | Specialization | Categorical | Specialization pursued by the candidate |
# | CollegeGPA | Continuous | Aggregate GPA at graduation |
# | CollegeCityID | NA/ID | A unique ID to identify the city in which the college is located in |
# | CollegeCityTier | Categorical | The tier of the city in which the college is located |
# | CollegeState | Categorical | Name of States |
# | GraduationYear | Date | Year of graduation (Bachelor’s degree) |
# | English | Continuous | Scores in AMCAT English section |
# | Logical | Continuous | Scores in AMCAT Logical section |
# | Quant | Continuous | Scores in AMCAT Quantitative section |
# | Domain | Continuous/Standardized | Scores in AMCAT’s domain module |
# | ComputerProgramming | Continuous | Score in AMCAT’s Computer programming section |
# | ElectronicsAndSemicon | Continuous | Score in AMCAT’s Electronics & Semiconductor Engineering section |
# | ComputerScience | Continuous | Score in AMCAT’s Computer Science section |
# | MechanicalEngg | Continuous | Score in AMCAT’s Mechanical Engineering section |
# | ElectricalEngg | Continuous | Score in AMCAT’s Electrical Engineering section |
# | TelecomEngg | Continuous | Score in AMCAT’s Telecommunication Engineering section |
# | CivilEngg | Continuous | Score in AMCAT’s Civil Engineering section |
# | conscientiousness | Continuous/Standardized | Scores in one of the sections of AMCAT’s personality test |
# | agreeableness | Continuous/Standardized | Scores in one of the sections of AMCAT’s personality test |
# | extraversion | Continuous/Standardized | Scores in one of the sections of AMCAT’s personality test |
# | neuroticism | Continuous/Standardized | Scores in one of the sections of AMCAT’s personality test |
# | openess_to_experience | Continuous/Standardized | Scores in one of the sections of AMCAT’s personality test |

# %% [markdown]
# #### Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Loading the Dataset

# %%
df = pd.read_excel(r'F:\Priya\Courses\Innomatics\Data Analysis Jupiter Notebook\Task 2\Task-2 (new)\aspiring_minds_employability_outcomes_2015.xlsx')
df.head()
# Out:
#   Unnamed: 0      ID   Salary        DOJ                  DOL  \
# 0      train  203097   420000 2012-06-01              present
# 1      train  579905   500000 2013-09-01              present
# 2      train  810601   325000 2014-06-01              present
# 3      train  267447  1100000 2011-07-01              present
# 4      train  343523   200000 2014-03-01  2015-03-01 00:00:00
#
#                 Designation    JobCity Gender        DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f 1990-02-19          84.3
# 1         assistant manager     Indore      m 1989-10-04          85.4
# 2          systems engineer    Chennai      f 1992-08-03          85.0
# 3  senior software engineer    Gurgaon      m 1989-12-05          85.6
# 4                       get    Manesar      m 1991-02-27          78.0
#
#                           10board  12graduation  12percentage  \
# 0  board ofsecondary education,ap          2007          95.8
# ...

# %%
df.shape
# Out:
# (3998, 39)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity',
#        'Gender', 'DOB', '10percentage', '10board', '12graduation',
#        '12percentage', '12board', 'CollegeID', 'CollegeTier', 'Degree',
#        'Specialization', 'collegeGPA', 'CollegeCityID', 'CollegeCityTier',
#        'CollegeState', 'GraduationYear', 'English', 'Logical', 'Quant',
#        'Domain', 'ComputerProgramming', 'ElectronicsAndSemicon',
#        'ComputerScience', 'MechanicalEngg', 'ElectricalEngg', 'TelecomEngg',
#        'CivilEngg', 'conscientiousness', 'agreeableness', 'extraversion',
#        'nueroticism', 'openess_to_experience'],
#       dtype='object')

# %%
df1 = df.drop(['Unnamed: 0'], axis=1)
df1.head(1)
# Out:
#        ID  Salary        DOJ      DOL              Designation    JobCity  \
# 0  203097  420000 2012-06-01  present  senior quality engineer  Bangalore
#
#   Gender        DOB  10percentage                         10board  \
# 0      f 1990-02-19          84.3  board ofsecondary education,ap
#
#    12graduation  12percentage                             12board  CollegeID  \
# 0          2007          95.8  board of intermediate education,ap       1141
#
#    CollegeTier       Degree        Specialization  collegeGPA  CollegeCityID  \
# 0            2  B.Tech/B.E.  computer engineering        78.0           1141
#
#    CollegeCityTier    CollegeState  GraduationYear  English  Logical  Quant  \
# 0                0  Andhra Pradesh            2011      515      585    525
#
#      Domain  ComputerProgramming  ElectronicsAndSemicon  ComputerScience  \
# 0  0.635979                  445                     -1               -1
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   int64
#  2   DOJ                    3998 non-null   datetime64[ns]
#  3   DOL                    3998 non-null   object
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   datetime64[ns]
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %% [markdown]
# **OBSERVATION:**
#
# Numerical Columns: 27
#
# Categorical Columns: 9
#
# Datetime Columns: 2

# %%
np.round(df1.describe(), 2)
# Out:
#                ID      Salary  10percentage  12graduation  12percentage  \
# count     3998.00     3998.00       3998.00       3998.00       3998.00
# mean    663794.54   307699.85         77.93       2008.09         74.47
# std     363218.25   212737.50          9.85          1.65         11.00
# min      11244.00    35000.00         43.00       1995.00         40.00
# 25%     334284.25   180000.00         71.68       2007.00         66.00
# 50%     639600.00   300000.00         79.15       2008.00         74.40
# 75%     990480.00   370000.00         85.67       2009.00         82.60
# max    1298275.00  4000000.00         97.76       2013.00         98.70
#
#        CollegeID  CollegeTier  collegeGPA  CollegeCityID  CollegeCityTier  \
# count    3998.00      3998.00     3998.00        3998.00          3998.00
# mean     5156.85         1.93       71.49        5156.85             0.30
# std      4802.26         0.26        8.17        4802.26             0.46
# ...

# %% [markdown]
# #### Data Cleaning

# %%
# df1['DOJ'].unique()

# %%
# df1['DOJ'].unique()

# %%
df1['DOJ'] = pd.to_datetime(df1['DOJ']).dt.date
df1['DOL'].replace('present', dt.datetime.today(), inplace = True)
df1['DOL'] = pd.to_datetime(df1['DOL']).dt.date
df1['JobPeriod'] = pd.to_datetime(df1['DOL']).dt.year-pd.to_datetime(df1['DOJ']).dt.year
df1['DOByear'] = pd.to_datetime(df1['DOB']).dt.year
df1.head(3)
# Out:
#        ID  Salary         DOJ         DOL              Designation    JobCity  \
# 0  203097  420000  2012-06-01  2023-04-19  senior quality engineer  Bangalore
# 1  579905  500000  2013-09-01  2023-04-19        assistant manager     Indore
# 2  810601  325000  2014-06-01  2023-04-19         systems engineer    Chennai
#
#   Gender        DOB  10percentage                         10board  \
# 0      f 1990-02-19          84.3  board ofsecondary education,ap
# 1      m 1989-10-04          85.4                            cbse
# 2      f 1992-08-03          85.0                            cbse
#
#    12graduation  12percentage                             12board  CollegeID  \
# 0          2007          95.8  board of intermediate education,ap       1141
# 1          2007          85.0                                cbse       5807
# 2          2010          68.2                                cbse         64
#
#    CollegeTier       Degree                             Specialization  \
# ...

# %%
df1['JobPeriod'].unique()
# Out:
# array([11, 10,  9, 12,  1,  4,  3,  0,  2,  8,  5, 13, 17,  6, 32, 16],
#       dtype=int64)

# %%
df1['GraduationYear'].unique()
# Out:
# array([2011, 2012, 2014, 2016, 2013, 2010, 2015, 2009, 2017,    0, 2007],
#       dtype=int64)

# %%
df1['12graduation'].unique()
# Out:
# array([2007, 2010, 2008, 2009, 2006, 2011, 2005, 1995, 2004, 2012, 2003,
#        2002, 2001, 1998, 2013, 1999], dtype=int64)

# %%
df1.GraduationYear.replace(0, df1.GraduationYear.mode()[0], inplace = True)
df1['12GradAge'] = abs(df1['12graduation']-df1['DOByear'])
df1['GradAge'] = abs(df1['GraduationYear']-df1['DOByear'])
df1.head()
# Out:
#        ID   Salary         DOJ         DOL               Designation  \
# 0  203097   420000  2012-06-01  2023-04-19   senior quality engineer
# 1  579905   500000  2013-09-01  2023-04-19         assistant manager
# 2  810601   325000  2014-06-01  2023-04-19          systems engineer
# 3  267447  1100000  2011-07-01  2023-04-19  senior software engineer
# 4  343523   200000  2014-03-01  2015-03-01                       get
#
#      JobCity Gender        DOB  10percentage                         10board  \
# 0  Bangalore      f 1990-02-19          84.3  board ofsecondary education,ap
# 1     Indore      m 1989-10-04          85.4                            cbse
# 2    Chennai      f 1992-08-03          85.0                            cbse
# 3    Gurgaon      m 1989-12-05          85.6                            cbse
# 4    Manesar      m 1991-02-27          78.0                            cbse
#
#    12graduation  12percentage                             12board  CollegeID  \
# ...

# %%
(df1==0).astype(int).sum(axis=0)
# Out:
# ID                          0
# Salary                      0
# DOJ                         0
# DOL                         0
# Designation                 0
# JobCity                     0
# Gender                      0
# DOB                         0
# 10percentage                0
# 10board                   350
# 12graduation                0
# 12percentage                0
# 12board                   359
# CollegeID                   0
# CollegeTier                 0
# Degree                      0
# Specialization              0
# collegeGPA                  0
# CollegeCityID               0
# CollegeCityTier          2797
# CollegeState                0
# GraduationYear              0
# English                     0
# Logical                     0
# Quant                       0
# Domain                      0
# ComputerProgramming         0
# ElectronicsAndSemicon       0
# ComputerScience             0
# MechanicalEngg              0
# ElectricalEngg              0
# ...

# %%
# df1[df1['10board']==0]

# %%
df1['10board'].mode()
# Out:
# 0    cbse
# dtype: object

# %%
df1['10board'].replace(0,'cbse', inplace = True)

# %%
# df1[df1['12board']==0]

# %%
df1['12board'].mode()
# Out:
# 0    cbse
# dtype: object

# %%
df1['12board'].replace(0,'cbse', inplace = True)

# %%
df1.isin([-1, 'NaN']).sum()
# Out:
# ID                          0
# Salary                      0
# DOJ                         0
# DOL                         0
# Designation                 0
# JobCity                   461
# Gender                      0
# DOB                         0
# 10percentage                0
# 10board                     0
# 12graduation                0
# 12percentage                0
# 12board                     0
# CollegeID                   0
# CollegeTier                 0
# Degree                      0
# Specialization              0
# collegeGPA                  0
# CollegeCityID               0
# CollegeCityTier             0
# CollegeState                0
# GraduationYear              0
# English                     0
# Logical                     0
# Quant                       0
# Domain                    246
# ComputerProgramming       868
# ElectronicsAndSemicon    2854
# ComputerScience          3096
# MechanicalEngg           3763
# ElectricalEngg           3837
# ...

# %%
df1['JobCity'].value_counts()
# Out:
# Bangalore           627
# -1                  461
# Noida               368
# Hyderabad           335
# Pune                290
#                    ...
# Tirunelvelli          1
# Ernakulam             1
# Nanded                1
# Dharmapuri            1
# Asifabadbanglore      1
# Name: JobCity, Length: 339, dtype: int64

# %%
df2=df1.copy(deep=True)

# %%
# Karnataka
df2['JobCity']=df1['JobCity'].replace(to_replace=['Bangalore', 'BANGLORE', 'banglore', 'Banagalore', 'Bangalore', 'BANGALORE', 'Banglore', 'Bengaluru', 'Asifabadbanglore', 'BANGLORE', 'Banaglore', 'bangalore', 'bengaluru', 'BAngalore'], value='Bangalore')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Bangalore '], value='Bangalore')
df2['JobCity']=df1['JobCity'].replace(to_replace=['BANGALORE '], value='Bangalore')
df2['JobCity']=df1['JobCity'].replace(to_replace=[' bangalore'], value='Bangalore')
df2['JobCity']=df1['JobCity'].replace(to_replace=['bangalore '], value='Bangalore')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Banglore '], value='Bangalore')

df2['JobCity']=df1['JobCity'].replace(to_replace=['Mangalore'], value='Mangaluru')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Mysore', 'mysore'], value='Mysuru')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Mysore '], value='Mysuru')

# Tamil Nadu
df2['JobCity']=df1['JobCity'].replace(to_replace=['Chennai', 'chennai', 'CHENNAI'], value='Chennai')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Chennai '], value='Chennai')
df2['JobCity']=df1['JobCity'].replace(to_replace=[' Chennai'], value='Chennai')
df2['JobCity']=df1['JobCity'].replace(to_replace=['chennai '], value='Chennai')

df2['JobCity']=df1['JobCity'].replace(to_replace=['Thiruvananthapuram'], value='Thiruvananthapuram')

# Telangana
df2['JobCity']=df1['JobCity'].replace(to_replace=['Hyderabad', 'HYDERABAD', 'hyderabad', 'hderabad', 'hyderabad(bhadurpally)', 'Miryalaguda'], value='Hyderabad')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Hyderabad '], value='Hyderabad')
df2['JobCity']=df1['JobCity'].replace(to_replace=['hyderabad '], value='Hyderabad')

# Odisha
df2['JobCity']=df1['JobCity'].replace(to_replace=['Bhubaneswar', 'Bhubaneshwar', 'bhubaneswar', 'Bhubneshwar', 'BHUBANESWAR'], value='Bhubaneswar')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Bhubaneswar '], value='Bhubaneswar')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Ganjam'], value='Ganjam')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Rourkela'], value='Rourkela')
df2['JobCity']=df1['JobCity'].replace(to_replace=['angul'], value='Angul')
df2['JobCity']=df1['JobCity'].replace(to_replace=['sambalpur', 'Sambalpur'], value='Sambalpur')
df2['JobCity']=df1['JobCity'].replace(to_replace=['orissa'], value='Odisha')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Baripada'], value='Baripada')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Rayagada', 'Odisha'], value='Rayagada')

# Delhi, NCR, Noida
df2['JobCity']=df1['JobCity'].replace(to_replace=['Gurgaon', 'gurgaon', 'GURGOAN', 'gurgoan', 'Gurga', 'Gurgaon', 'Gurgoan', 'GURAGAON', 'GURGAON'], value='Gurgaon')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Gurgaon '], value='Gurgaon')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Delhi', 'delhi', 'New Delhi', 'new dehli', 'NEW DELHI', 'Delhi/NCR', 'new delhi', 'DELHI', 'ncr', 'New delhi'], value='Delhi')
df2['JobCity']=df1['JobCity'].replace(to_replace=[' Delhi'], value='Delhi')
df2['JobCity']=df1['JobCity'].replace(to_replace=['New Delhi '], value='Delhi')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Noida', 'NOIDA', 'noida', 'Greater Noida', 'Greater noida', 'Nouda', 'A-64,sec-64,noida', 'GREATER NOIDA', 'Greater NOIDA', 'Noida'], value='Noida')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Noida '], value='Noida')
df2['JobCity']=df1['JobCity'].replace(to_replace=['noida '], value='Noida')
df2['JobCity']=df1['JobCity'].replace(to_replace=['Ghaziabad', 'Indirapuram', 'Ghaziabad', 'Sahibabad', 'ghaziabad', 'Gajiabaad', 'shahibabad', 'Gaziabaad', 'Gaziabad'], value='Gaziabad')

# UP
df2['JobCity']=df1['JobCity'].replace(to_replace=['Maharajganj'], value='Maharajganj')
df2['JobCity']=df1['JobCity'].replace(['Lucknow', 'Lucknow ', 'LUCKNOW', 'lucknow'], 'Lucknow')
df2['JobCity']=df1['JobCity'].replace(['meerut', 'MEERUT', 'Meerut'], 'Meerut')
df2['JobCity']=df1['JobCity'].replace(['Kanpur', 'Kanpur ', 'kanpur', 'KANPUR'], 'Kanpur')
df2['JobCity']=df1['JobCity'].replace(['Muzaffarpur', 'muzzafarpur'], 'Muzaffarpur')

# Gujarat
df2['JobCity']=df1['JobCity'].replace(['Ahmedabad', 'Ahmedabad ', 'ahmedabad'], 'Ahmedabad')
df2['JobCity']=df1['JobCity'].replace(['Gandhi Nagar', 'Gandhinagar', 'Gandhinagar '], 'Gandhi Nagar')
df2['JobCity']=df1['JobCity'].replace(['KOTA', 'Kota'], 'Kota')
df2['JobCity']=df1['JobCity'].replace(['Jamnagar', 'jamnagar'], 'Jamnagar')

# Haryana
df2['JobCity']=df1['JobCity'].replace(['Manesar', 'manesar'], 'Manesar')
df2['JobCity']=df1['JobCity'].replace(['mohali', 'Mohali', 'mohali'], 'Mohali')
df2['JobCity']=df1['JobCity'].replace(['Punchkula'], 'Punchkula')
df2['JobCity']=df1['JobCity'].replace(['Panchkula '],'Punchkula')

# MP
df2['JobCity']=df1['JobCity'].replace(['Indore', 'indore'], 'Indore')
df2['JobCity']=df1['JobCity'].replace(['BHOPAL', 'Bhopal'], 'Bhopal')
df2['JobCity']=df1['JobCity'].replace(['Bhopal '], 'Bhopal')
df2['JobCity']=df1['JobCity'].replace(['Shahdol', 'SHAHDOL'], 'Shahdol')

# Maharashtra
df2['JobCity']=df1['JobCity'].replace([' Mumbai'], 'Mumbai')
df2['JobCity']=df1['JobCity'].replace([' mumbai'], 'Mumbai')
df2['JobCity']=df1['JobCity'].replace(['Mumbai '], 'Mumbai')
df2['JobCity']=df1['JobCity'].replace(['mumbai '], 'Mumbai')
df2['JobCity']=df1['JobCity'].replace(['Navi Mumbai', 'Mumbai', 'THANE', 'mumbai', 'NAVI MUMBAI', 'Navi mumbai', 'MUMBAI', 'Thane', 'Khopoli', 'thane'], 'Mumbai')
df2['JobCity']=df1['JobCity'].replace(['Pune', 'pune', 'Pune', 'PUNE', 'punr', 'Pune'], 'Pune')
df2['JobCity']=df1['JobCity'].replace(['Pune '], 'Pune')
df2['JobCity']=df1['JobCity'].replace([' Pune'], 'Pune')
df2['JobCity']=df1['JobCity'].replace(['pune '], 'Pune')
df2['JobCity']=df1['JobCity'].replace(['Nasikcity', 'Nashik'], 'Nashik')
df2['JobCity']=df1['JobCity'].replace(['Nagpur '], 'Nagpur')
df2['JobCity']=df1['JobCity'].replace(['latur (Maharashtra )'], 'Latur')

# Rajasthan
df2['JobCity']=df1['JobCity'].replace(['Jaipur', 'jaipur', 'jAipur', ' Jaipur', 'Jaipur ', 'jaipur ', ' jaipur'], 'Jaipur')
df2['JobCity']=df1['JobCity'].replace(['Pilani', 'PILANI'], 'Pilani')
df2['JobCity']=df1['JobCity'].replace(['Udaipur', 'udaipur'], 'Udaipur')
df2['JobCity']=df1['JobCity'].replace(['Pilani', 'PILANI'], 'Pilani')

# Kolkata
df2['JobCity']=df1['JobCity'].replace(['Kolkata, kolkata, KOLKATA, Kolkata`', 'Kolkata', 'Kolkata '], 'Kolkata')
df2['JobCity']=df1['JobCity'].replace(['Siliguri', 'Siliguri '], 'Siliguri')

# Chattisgarh
df2['JobCity']=df1['JobCity'].replace(['raipur', 'Raipur'], 'Raipur')
df2['JobCity']=df1['JobCity'].replace(['ranchi', 'Ranchi', 'Ranchi '], 'Ranchi')

# Uttrakhand
df2['JobCity']=df1['JobCity'].replace(['Dehradun', 'dehradun'], 'Dehradun')

# AP
df2['JobCity']=df1['JobCity'].replace(['vsakhapttnam', 'VIZAG', 'vizag', 'Visakhapatnam', 'Vijayawada', 'Vizag'], 'Visakhapatnam')
df2['JobCity']=df1['JobCity'].replace(['Tirupathi', 'Tirupati'], 'Tirupati')

# Tamil Nadu
df2['JobCity']=df1['JobCity'].replace(['coimbatore', 'Coimbatore'], 'Coimbatore')
df2['JobCity']=df1['JobCity'].replace([ 'Madurai', 'Madurai '], 'Madurai')

# Kerala
df2['JobCity']=df1['JobCity'].replace(['trivandrum', 'Trivandrum',  'TRIVANDRUM', 'Trivandrum ', 'Technopark, Trivandrum'], 'Trivandrum')
df2['JobCity']=df1['JobCity'].replace(['Kochi/Cochin', 'Kochi'], 'Kochi')

# Haryana
df2['JobCity']=df1['JobCity'].replace(['karnal', 'Karnal'], 'Karnal')

# Punjab
df2['JobCity']=df1['JobCity'].replace(['Ambala City', 'Ambala'], 'Ambala')
df2['JobCity']=df1['JobCity'].replace(['chandigarh', 'Chandigarh ', 'Chandigarh'], 'Chandigarh')

# Pondicherry
df2['JobCity']=df1['JobCity'].replace(['Pondicherry', 'pondy', 'pondi'], 'Pondicherry')

# %%
df2['JobCity'].unique()
# Out:
# array(['Bangalore', 'Indore', 'Chennai', 'Gurgaon', 'Manesar',
#        'Hyderabad', 'Banglore', 'Noida', 'Kolkata', 'Pune', -1, 'mohali',
#        'Jhansi', 'Delhi', 'Hyderabad ', 'Bangalore ', 'noida', 'delhi',
#        'Bhubaneswar', 'Navi Mumbai', 'Mumbai', 'New Delhi', 'Mangalore',
#        'Rewari', 'Gaziabaad', 'Bhiwadi', 'Mysore', 'Rajkot',
#        'Greater Noida', 'Jaipur', 'noida ', 'HYDERABAD', 'mysore',
#        'THANE', 'Maharajganj', 'Thiruvananthapuram', 'Punchkula',
#        'Bhubaneshwar', 'Pune ', 'coimbatore', 'Dhanbad', 'Lucknow',
#        'Trivandrum', 'kolkata', 'mumbai', 'Gandhi Nagar', 'Una',
#        'Daman and Diu', 'chennai', 'GURGOAN', 'vsakhapttnam', 'pune',
#        'Nagpur', 'Bhagalpur', 'new delhi - jaisalmer', 'Coimbatore',
#        'Ahmedabad', 'Kochi/Cochin', 'Bankura', 'Bengaluru', 'Mysore ',
#        'Kanpur ', 'jaipur', 'Gurgaon ', 'bangalore', 'CHENNAI',
#        'Vijayawada', 'Kochi', 'Beawar', 'Alwar', 'NOIDA', 'Greater noida',
# ...

# %%
df2['JobCity'].mode()
# Out:
# 0    Bangalore
# dtype: object

# %%
df2['JobCity'].value_counts()
# Out:
# Bangalore           627
# -1                  461
# Noida               368
# Hyderabad           335
# Pune                290
#                    ...
# indore                1
# Salem                 1
# Punchkula             1
# Gandhinagar           1
# Asifabadbanglore      1
# Name: JobCity, Length: 337, dtype: int64

# %%
# df2['JobCity']=df1['JobCity'].replace('Bangalore', 'Bengaluru')

# %%
df2['JobCity']=df1['JobCity'].replace(-1, 'Bangalore')

# %%
df2['JobCity'].value_counts()
# Out:
# Bangalore           1088
# Noida                368
# Hyderabad            335
# Pune                 290
# Chennai              272
#                     ...
# Asansol                1
# Tirunelvelli           1
# Ernakulam              1
# Nanded                 1
# Asifabadbanglore       1
# Name: JobCity, Length: 338, dtype: int64

# %%
# 'Bangalore, banglore, Banagalore, BANGALORE, Banglore, Bengaluru, Asifabadbanglore, BANGLORE, Banaglore, bangalore, bengaluru, BAngalore', 'Bengaluru'
# 'Bangalore ', 'Bengaluru'
# 'BANGALORE ', 'Bengaluru'
# ' bangalore', 'Bengaluru'
# 'bangalore ',
# 'Banglore ',


# 'Mangalore', 'Mangaluru'
# 'Mysore, mysore', 'Mysuru'
# 'Mysore '
# 'Chennai, chennai, CHENNAI', 'Chennai'
# 'Chennai '
# ' Chennai'
# 'chennai '

# 'Thiruvananthapuram', 'Thiruvananthapuram'

# 'Hyderabad, HYDERABAD, hyderabad, hderabad, hyderabad(bhadurpally), Miryalaguda', 'Hyerabad'
# 'hyderabad '

# 'Bhubaneswar, Bhubaneshwar, bhubaneswar, Bhubneshwar, BHUBANESWAR', 'Bhubaneswar'
# 'Bhubaneswar '
# 'Ganjam'
# 'Rourkela'
# 'angul'
# 'sambalpur','Sambalpur'
# 'orissa'
# 'Baripada'
# 'Rayagada, Odisha'

# 'Gurgaon, gurgaon, GURGOAN, gurgoan, Gurga , Gurgaon, Gurgoan, GURAGAON, GURGAON', 'Gurgaon'
# 'Gurgaon '
# 'Maharajganj', 'Maharajganj'

# 'Manesar, manesar', 'Manesar'
# 'mohali', 'Mohali'
# 'Punchkula', 'Punchkula'
# 'Jhansi', 'Jhansi'
# 'Indore, indore', 'Indore'
# 'BHOPAL, Bhopal', 'Bhopal'
# 'Bhopal '
# 'Gwalior'
# 'singaruli'
# 'Shahdol', 'SHAHDOL'
# 'Jabalpur'

# 'Delhi, delhi, New Delhi, new dehli, NEW DELHI, Delhi/NCR, new delhi, DELHI, ncr, New delhi', 'Delhi'
# 'New Delhi ', 'Delhi'
# 'Noida, NOIDA, noida, Greater Noida, Greater noida, Nouda, A-64,sec-64,noida, GREATER NOIDA, Greater NOIDA, Noida', 'Noida'
# 'Noida ',
# 'noida ',  
# 'Ghaziabad, Indirapuram, Ghaziabad, Sahibabad, ghaziabad, Gajiabaad, shahibabad, Gaziabaad, Gaziabad', 'Gaziabad'

# 'Kolkata, kolkata, KOLKATA, Kolkata`', 'Kolkata', 'Kolkata '
# 'Siliguri', 'Siliguri '
# 'Howrah'
# 'Asansol'
# 'Bankura'
# 'Haldia'
# 'kharagpur'
# 'Burdwan'
# 'Durgapur'


# 'Jowai'
# 'Guwahati',
# 'Mainpuri'

# 'Navi Mumbai, Mumbai, THANE, mumbai, NAVI MUMBAI, Navi mumbai, MUMBAI, Thane, Khopoli, thane', 'Mumbai'
# 'Pune, pune', 'Pune', 'PUNE', 'punr', 'Pune'
# 'Pune ',
# ' Pune', 'pune '
# 'Karad', 'latur (Maharashtra )','Nagpur', 'Ratnagiri', 'Aurangabad', 'Nasikcity', 'Nagpur ', 'Nanded', 'Ahmednagar', 'Nashik'
#  'kolhapur', 'Chandrapur'

# 'Rewari', 'Rewari'
# 'Bhiwadi', 'Bhiwadi'
# 'Rajkot', 'Rajkot'
# 'Jaipur, jaipur, jAipur', 'Jaipur'
# 'Beawar', 
# 'Alwar',
# 'Jodhpur'
# 'Pilani', 'PILANI'
# 'Dausa'
# 'Rajasthan'
# 'Bundi'
# 'Bikaner',
# 'Udaipur', 'udaipur'
# 'Neemrana'
# 'SADULPUR,RAJGARH,DISTT-CHURU,RAJASTHAN'

# 'Dhanbad', 'Jamshedpur'

# 'raipur', 'Raipur', 'Raigarh', 'ranchi', 'Ranchi', 'Ranchi ', 'Bilaspur', 'Jagdalpur', 'Bhilai'

# 'Haridwar', 'Dehradun', 'dehradun', 'Roorkee', 'Dharamshala', 'Pantnagar', 'Jaspur', 'Joshimath', 'Rudrapur'

# 'Lucknow', 'Lucknow ', 'LUCKNOW', 'lucknow', 'meerut', 'MEERUT', 'Meerut', 'Kanpur', 'Kanpur ', 'kanpur', 'KANPUR', 'Muzaffarpur', 'muzzafarpur', 'Faridabad', 
# 'Bulandshahar', 'Unnao', 'RAE BARELI', 'Bareli', 'Gorakhpur', 'Muzaffarnagar', 'Agra', 
# 'Varanasi', 'Allahabad', 'Gonda',


# 'Gandhi Nagar', 'Gandhinagar',  'Gandhinagar ', 'Una', 'Daman and Diu', 'Dammam', 'Ahmedabad', 'Ahmedabad ', 'ahmedabad', 'Baroda', 'Vadodara'
# 'KOTA', 'Kota', 'Jamnagar', 'jamnagar', 'Surat', 'Bharuch', 'vapi'

# 'vsakhapttnam', 'VIZAG', 'vizag', 'Visakhapatnam', 'Vijayawada', 'Vizag', 'kakinada', 'Kurnool', 'Nellore', 'Secunderabad',
# 'Tirupathi', 'Tirupati', 'Ongole'

# 'Gulbarga', 'Belgaum', 'Hubli', 'Hospete', 'Bellary', 'Tornagallu'

# 'Bhagalpur',
# 'new delhi - jaisalmer', 'Chennai & Mumbai', 'kudankulam ,tarapur', 'Navi Mumbai , Hyderabad', 'Chennai, Bangalore'

# 'keral', 'Trichur', 'trivandrum', 'Trivandrum',  'TRIVANDRUM', 'Trivandrum ', 'Technopark, Trivandrum', 'Kochi/Cochin', 'Kochi',
# 'Ernakulam', 'Calicut', 'Muvattupuzha', 'Kochi/Cochin, Chennai and Coimbatore', 'Trichy'
# 'Salem', 'coimbatore', 'Coimbatore', 'Madurai', 'Madurai ', 'CHEYYAR', 'Tirunelvelli', 'Vellore', 'Nagari', 'Dharmapuri', 'Vandavasi'
# 'Mettur, Tamil Nadu ', ' ariyalur'

# 'Australia', 'Dubai', 'LONDON', 'Kalmar, Sweden', 'RAS AL KHAIMAH', 'Al Jubail,Saudi Arabia', 'Johannesburg', 'Jeddah Saudi Arabia'

# 'Pondicherry', 'pondy', 'pondi', 'AM', 'india', 'Jammu', 
# 'PATNA', 'Patna', 'patna', 'bihar'  


# 'Nalagarh', 'Shimla', 'Gagret', 'kala amb ', 'Baddi HP'

# 'haryana', 'karnal', 'Karnal', 'Hissar', 'sonepat', 'Panchkula ', 'Panchkula', 'Rohtak', 'Sonipat', 'Jhajjar', 'Dharuhera',
# 'Bahadurgarh',  'Yamuna Nagar', 'sampla'
# 'Rajpura', 'Ambala City', 'Patiala', 'Ambala', 'Jalandhar', 'chandigarh', 'Chandigarh ', 'Chandigarh', 'Bathinda', 'Mohali', 
# 'Ludhiana', 'Phagwara'

# %%
df2.Domain.unique()
# Out:
# array([ 0.63597876,  0.96060325,  0.45087658,  0.97439611,  0.12450207,
#        -1.        ,  0.35653649,  0.8295846 ,  0.69447933,  0.49359639,
#         0.76567358,  0.9682375 ,  0.22948175,  0.53838689,  0.30840058,
#         0.91139528,  0.56326782,  0.86468541,  0.64938971,  0.74475835,
#         0.88412251,  0.88162007,  0.20739217,  0.48674701,  0.67074315,
#         0.62264292,  0.41383826,  0.52592258,  0.73579571,  0.13044174,
#         0.23780284,  0.11213944,  0.37755142,  0.06696071,  0.08005528,
#         0.92564577,  0.84312373,  0.91686996,  0.78330354,  0.60005718,
#         0.79293628,  0.79358061,  0.16563309,  0.75537512,  0.99990456,
#         0.33878635,  0.91077016,  0.98205712,  0.84224832,  0.01854094,
#         0.05316031,  0.94211655,  0.12301673,  0.48834798,  0.37605959,
#         0.0587928 ,  0.10487136,  0.60064396,  0.70409041,  0.14478989,
#         0.81941653,  0.65576694,  0.02106623,  0.44461772,  0.83762073,
# ...

# %%
df2.Domain.median()
# Out:
# 0.622642915849938

# %%
df2.Domain = df2.Domain.replace(-1, df2.Domain.median())

# %%
df2.Domain.value_counts()
# Out:
# 0.622643    359
# 0.538387    110
# 0.486747    106
# 0.744758    103
# 0.376060    103
#            ...
# 0.924610      1
# 0.184772      1
# 0.042192      1
# 0.790882      1
# 0.938588      1
# Name: Domain, Length: 242, dtype: int64

# %%
df2['10board'].unique()
# Out:
# array(['board ofsecondary education,ap', 'cbse', 'state board',
#        'mp board bhopal', 'icse',
#        'karnataka secondary school of examination', 'up',
#        'karnataka state education examination board', 'ssc',
#        'kerala state technical education', 'bseb',
#        'state board of secondary education, andhra pradesh',
#        'matriculation', 'gujarat state board', 'karnataka state board',
#        'wbbse', 'maharashtra state board', 'icse board', 'up board',
#        'board of secondary education(bse) orissa',
#        'little jacky matric higher secondary school',
#        'uttar pradesh board', 'bsc,orissa', 'mp board', 'upboard',
#        'matriculation board', 'j & k bord', 'rbse',
#        'central board of secondary education', 'pseb', 'jkbose',
#        'haryana board of school education,(hbse)', 'metric', 'ms board',
#        'kseeb', 'stateboard', 'maticulation',
#        'karnataka secondory education board', 'mumbai board', 'sslc',
# ...

# %%
list_10board = []
for i in df2['10board']:
    if ('icse' in i):
        list_10board.append('ICSE')
    elif ('council for indian school certificate examination' in i):
        list_10board.append('ICSE')
    elif('cbse' in i):
        list_10board.append('CBSE')
    elif('central board of secondary education' in i):
        list_10board.append('CBSE')
    elif('delhi' in i):
        list_10board.append('CBSE')
    elif('cbsc' in i):
        list_10board.append('CBSE')
    else:
        list_10board.append('State Board')
df2['10board']=list_10board

# %%
df2['10board'].value_counts()
# Out:
# State Board    1947
# CBSE           1766
# ICSE            285
# Name: 10board, dtype: int64

# %%
df2['10board'].unique()
# Out:
# array(['State Board', 'CBSE', 'ICSE'], dtype=object)

# %%
df2['12board'].unique()
# Out:
# array(['board of intermediate education,ap', 'cbse', 'state board',
#        'mp board', 'isc', 'icse', 'karnataka pre university board', 'up',
#        'p u board, karnataka', 'dept of pre-university education', 'bie',
#        'kerala state hse board', 'up board', 'bseb', 'chse', 'puc',
#        ' upboard',
#        'state  board of intermediate education, andhra pradesh',
#        'karnataka state board',
#        'west bengal state council of technical education', 'wbchse',
#        'maharashtra state board', 'ssc', 'isc board',
#        'sda matric higher secondary school', 'uttar pradesh board', 'ibe',
#        'chsc', 'board of intermediate', 'isce', 'upboard', 'sbtet',
#        'hisher seconadry examination(state board)', 'pre university',
#        'borad of intermediate', 'j & k board',
#        'intermediate board of andhra pardesh', 'rbse',
#        'central board of secondary education', 'jkbose', 'hbse',
# ...

# %%
list_12board=[]
for i in df2['12board']:
    if ('icse' in i):
        list_12board.append('ICSE')
    elif('cbse' in i):
        list_12board.append('CBSE')
    elif('nios' in i):
        list_12board.append('National Board')
    elif('diploma' in i):
        list_12board.append('Diploma')
    elif('technical' in i):
        list_12board.append('Technical')
    elif('university' in i):
        list_12board.append('University')
    else:
        list_12board.append('State Board')
df2['12board']=list_12board
df2['12board'].value_counts()
# Out:
# State Board       2045
# CBSE              1761
# ICSE               130
# University          32
# Technical           15
# Diploma              8
# National Board       7
# Name: 12board, dtype: int64

# %%
df2.Specialization.unique()
# Out:
# array(['computer engineering',
#        'electronics and communication engineering',
#        'information technology', 'computer science & engineering',
#        'mechanical engineering', 'electronics and electrical engineering',
#        'electronics & telecommunications',
#        'instrumentation and control engineering', 'computer application',
#        'electronics and computer engineering', 'electrical engineering',
#        'applied electronics and instrumentation',
#        'electronics & instrumentation eng',
#        'information science engineering', 'civil engineering',
#        'mechanical and automation', 'industrial & production engineering',
#        'control and instrumentation engineering',
#        'metallurgical engineering',
#        'electronics and instrumentation engineering',
#        'electronics engineering', 'ceramic engineering',
#        'chemical engineering', 'aeronautical engineering', 'other',
# ...

# %%
Specialization_Map=\
{'computer engineering' : 'CS',
 'electronics and communication engineering' : 'EC',
 'information technology' : 'IT',
 'computer science & engineering' : 'CS',
 'mechanical engineering' : 'ME',
 'electronics and electrical engineering' : 'EC',
 'electronics & telecommunications' : 'EC',
 'instrumentation and control engineering' : 'I&C', 
 'computer application' : 'CS',
 'electronics and computer engineering' : 'EC', 
 'electrical engineering' : 'EC',
 'applied electronics and instrumentation' : 'EC',
 'electronics & instrumentation eng' : 'EC',
 'information science engineering' : 'IT', 
 'civil engineering' : 'CE',
 'mechanical and automation' : 'ME', 
 'industrial & production engineering' : 'Other',
 'control and instrumentation engineering' : 'EC',
 'metallurgical engineering' : 'Other',
 'electronics and instrumentation engineering' : 'EC',
 'electronics engineering' : 'EC', 
 'ceramic engineering' : 'Other',
 'chemical engineering' : 'Other', 
 'aeronautical engineering' : 'AE', 
 'other' : 'Other',
 'biotechnology' : 'BT', 
 'embedded systems technology' : 'EC',
 'electrical and power engineering' : 'EC',
 'computer science and technology' : 'CS', 
 'mechatronics' : 'ME',
 'automobile/automotive engineering' : 'ME', 
 'polymer technology' : 'Other',
 'mechanical & production engineering' : 'ME',
 'power systems and automation' : 'EC', 
 'instrumentation engineering' : 'IN',
 'telecommunication engineering' : 'EC',
 'industrial & management engineering' : 'Other', 
 'industrial engineering' : 'Other',
 'computer and communication engineering' : 'CS',
 'information & communication technology' : 'IT', 
 'information science' : 'CS',
 'internal combustion engine' : 'ME', 
 'computer networking' : 'CS',
 'biomedical engineering' : 'BM', 
 'electronics' : 'EC', 
 'computer science' : 'CS'}

# %%
df2.Specialization = df2.Specialization.map(Specialization_Map)
df2.Specialization.value_counts()
# Out:
# CS       1599
# EC       1381
# IT        689
# ME        217
# Other      39
# CE         29
# I&C        20
# BT         15
# IN          4
# AE          3
# BM          2
# Name: Specialization, dtype: int64

# %%
df2['Specialization'].unique()
# Out:
# array(['CS', 'EC', 'IT', 'ME', 'I&C', 'CE', 'Other', 'AE', 'BT', 'IN',
#        'BM'], dtype=object)

# %%
df2['Designation'].replace({"ase":"associate software engineer", "get":"graduate engineer trainee",
                           "graduate trainee engineer":"graduate engineer trainee", "software engineer associate":"associate software engineer",
                           "business development managerde":"business development manager",
                           "jr. software developer":"junior software developer", "software trainee engineer":"software engineer trainee",
                           "asst. manager":"assistant manager", "dotnet developer":".net developer",
                           "qa analyst":"quality assurance analyst","associate software engg":"associate software engineer",
                           "assistant system engineer - trainee":"assistant system engineer trainee",
                           "software eng":"software engineer", "software engineering associate":"software engineer associate",
                           "software enginner":"software engineer", "systems engineer":"system engineer"}, inplace=True)

# %%
df2['Designation_Position']=df2['Designation'].str.title()
df2['Designation_Position']
# Out:
# 0           Senior Quality Engineer
# 1                 Assistant Manager
# 2                   System Engineer
# 3          Senior Software Engineer
# 4         Graduate Engineer Trainee
#                    ...
# 3993              Software Engineer
# 3994               Technical Writer
# 3995    Associate Software Engineer
# 3996             Software Developer
# 3997        Senior Systems Engineer
# Name: Designation_Position, Length: 3998, dtype: object

# %%
Designation_List=[]
for i in df2['Designation']:
    if ('senior' in i and 'engineer' not in i):
        Designation_List.append('Senior')
    elif('trainee'in i and 'engineer' not in i):
        Designation_List.append('Trainee')
    elif('engineer' in i and 'senior' not in i):
        Designation_List.append('Engineer')
    elif('associate' in i and 'senior' not in i):
        Designation_List.append('Associate')
    elif('developer' in i and 'senior' not in i):
        Designation_List.append('Developer')
    elif('manager' in i and 'senior' not in i):
        Designation_List.append('Manager')
    elif('analyst' in i):
        Designation_List.append('Analyst')
    elif('consultant' in i):
        Designation_List.append('Consultant')
    elif('executive' in i):
        Designation_List.append('Executive')
    elif('designer' in i):
        Designation_List.append('Designer')
    else:
        Designation_List.append('Others')
df2.Designation=Designation_List
df2.Designation.value_counts()
# Out:
# Engineer      2018
# Developer      668
# Others         518
# Analyst        402
# Manager        123
# Associate       65
# Executive       62
# Trainee         57
# Senior          43
# Designer        23
# Consultant      19
# Name: Designation, dtype: int64

# %%
df2['Personality Trait Score']=((df2['conscientiousness']+df2['agreeableness']+df2['extraversion']+df2['nueroticism']+df2['openess_to_experience'])/5)
df2['Personality Trait Score'].head()
# Out:
# 0    0.644560
# 1    0.328220
# 2    0.390060
# 3   -0.256000
# 4   -0.453574
# Name: Personality Trait Score, dtype: float64

# %%
df2['Gender'].replace('f','Female', inplace = True)
df2['Gender'].replace('m', 'Male', inplace = True)

# %%
df2.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism', 'openess_to_experience',
#        'JobPeriod', 'DOByear', '12GradAge', 'GradAge', 'Designation_Position',
#        'Personality Trait Score'],
#       dtype='object')

# %%
df3 = df2.drop(columns=['ComputerProgramming','ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg','ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness','agreeableness', 'extraversion', 'nueroticism', 'openess_to_experience','DOJ', 'DOL','DOB', 'CollegeID', 'English', 'Logical', 'Quant'])
df3.head()
# Out:
#        ID   Salary Designation    JobCity  Gender  10percentage      10board  \
# 0  203097   420000      Others  Bangalore  Female          84.3  State Board
# 1  579905   500000     Manager     Indore    Male          85.4         CBSE
# 2  810601   325000    Engineer    Chennai  Female          85.0         CBSE
# 3  267447  1100000      Others    Gurgaon    Male          85.6         CBSE
# 4  343523   200000    Engineer    Manesar    Male          78.0         CBSE
#
#    12graduation  12percentage      12board  CollegeTier       Degree  \
# 0          2007          95.8  State Board            2  B.Tech/B.E.
# 1          2007          85.0         CBSE            2  B.Tech/B.E.
# 2          2010          68.2         CBSE            2  B.Tech/B.E.
# 3          2007          83.6         CBSE            1  B.Tech/B.E.
# 4          2008          76.8         CBSE            2  B.Tech/B.E.
#
#   Specialization  collegeGPA  CollegeCityID  CollegeCityTier    CollegeState  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       3998 non-null   int64
#  1   Salary                   3998 non-null   int64
#  2   Designation              3998 non-null   object
#  3   JobCity                  3998 non-null   object
#  4   Gender                   3998 non-null   object
#  5   10percentage             3998 non-null   float64
#  6   10board                  3998 non-null   object
#  7   12graduation             3998 non-null   int64
#  8   12percentage             3998 non-null   float64
#  9   12board                  3998 non-null   object
#  10  CollegeTier              3998 non-null   int64
#  11  Degree                   3998 non-null   object
#  12  Specialization           3998 non-null   object
#  13  collegeGPA               3998 non-null   float64
# ...

# %% [markdown]
# #### Saving the Cleaned Data

# %%
df3.to_csv('EDA_AMEO_Data_Cleaned.csv')

# %% [markdown]
# #### EDA

# %% [markdown]
# ##### Univariate Analysis - Numerical columns

# %% [markdown]
# ##### Salary

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(df3['Salary'])
plt.show()

# %% [markdown]
# **OBSERVATION:**
# Outliers are their in Salary column

# %%
df3.hist(column = 'Salary', alpha=0.5, edgecolor='black', figsize = (10, 7))
plt.show()

# %%
# plt.figure(figsize=(10, 7))
df3['Salary'].describe()[1:].plot(color = 'cyan', marker = 'D', markersize = 7)
# plt.plot(df3.index, df3.Salary.describe(), markevery=1, marker='d')
plt.title('Statistics Summary for Salary')
plt.xlabel('Statistical Measures')
plt.tight_layout()
plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# 1. BoxPlot: Presence of Outliers and a lot of High Salary datapoints are present in dataset
#
# 2. Histogram: Salary data is highly and positively skewed on the right side
#
# 3. Statistics Summary: High variations are present in Salary data

# %% [markdown]
# ##### Age

# %%
plt.figure(figsize=(10, 7))
boxplot_df = pd.DataFrame(data = df3, columns = ['12GradAge','GradAge'])
boxplot_df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df3.hist(column=["12GradAge", "GradAge"], color = 'yellow', alpha=0.5, edgecolor='black', figsize = (10, 7))
plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# 12th Graduation Age: 17-18 yrs
#
# Graduation Age: 21-24

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15,5))
fig.suptitle('Statistics Summary for Age')
axes[0].set_title('Statistics Summary for 12GradAge')
axes[1].set_title('Statistics Summary for GradAge')

# axes[2].set_title('Count of EMMC')

df3['12GradAge'].describe()[1:].plot(color = 'green', marker = 'D', markersize = 7, ax=axes[0])
df3['GradAge'].describe()[1:].plot(color = 'blue', marker = 'D', markersize = 7, ax=axes[1])
# sns.countplot(df['SSD GB'], ax=axes[0])
# sns.countplot(df['HDD GB'], ax=axes[1])
# sns.countplot(df['EMMC GB'], ax=axes[2])
axes[0].set_xlabel('Statistical Measures of 12GradAge')
axes[1].set_xlabel('Statistical Measures of GradAge')
# plt.xlabel('Statistical Measures')
plt.show()

# %%
plt.figure(figsize=(10,5))
# ax = sns.barplot(x='RAM Size GB',y='MRP',data=df, palette='tab20', edgecolor = 'black')
ax=sns.countplot(df3['GradAge'], palette='Pastel1', edgecolor = 'black')
plt.xticks(fontsize=15)
plt.title("Count of Enployees by their GradAge", fontsize=15, color='black');

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# 1. Most of the student Graduate college in age 22yrs followed by 21yrs and 23yrs
# 2. Majority of graduate students age is between 21-25 years

# %%
print("Age of Yongest Employee :", df3['GradAge'].min())
print("Age of Oldest Employee :", df3['GradAge'].max())
print("Average Age of Employees :", df3['GradAge'].mean())
# Out:
# Age of Yongest Employee : 17
# Age of Oldest Employee : 34
# Average Age of Employees : 22.181840920460232

# %% [markdown]
# ##### Percentage

# %%
plt.figure(figsize=(10, 7))
boxplot_df = pd.DataFrame(data = df3, columns = ['12percentage','10percentage'])
boxplot_df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df3.hist(column=["12percentage", "10percentage"], color = 'green', alpha=0.5, edgecolor='black', figsize = (10, 7))
plt.show()

# %% [markdown]
# **OBSERVATION:**
# Most of the student's percentage for 12th and 10th is between 60% - 90%

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15,5))
fig.suptitle('Statistics Summary for Percentage')
axes[0].set_title('Statistics Summary for 12percentage')
axes[1].set_title('Statistics Summary for 10percentage')

# axes[2].set_title('Count of EMMC')

df3['12percentage'].describe()[1:].plot(color = 'orange', marker = 'D', markersize = 7, ax=axes[0])
df3['10percentage'].describe()[1:].plot(color = 'cyan', marker = 'D', markersize = 7, ax=axes[1])
# sns.countplot(df['SSD GB'], ax=axes[0])
# sns.countplot(df['HDD GB'], ax=axes[1])
# sns.countplot(df['EMMC GB'], ax=axes[2])
axes[0].set_xlabel('Statistical Measures of 12percentage')
axes[1].set_xlabel('Statistical Measures of 10percentage')
# plt.xlabel('Statistical Measures')
plt.show()

# %% [markdown]
# ##### Collage GPA

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(df3['collegeGPA'])
plt.show()

# plt.figure(figsize=(7, 5))
# boxplot_df = pd.DataFrame(data = df3, columns = ['collegeGPA'])
# boxplot_df.boxplot()

# %%
df3.hist(column=["collegeGPA"], color='orange', alpha=0.5, edgecolor='black', figsize = (10, 7))
plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Histogram: Majority of the students College GPA is between 60-80 percent
#
# Boxplot: Presence of outliers on both low and high extreme values

# %%
df3['collegeGPA'].describe()[1:].plot(color = 'magenta', marker = 'D', markersize = 7)
# plt.plot(df3.index, df3.Salary.describe(), markevery=1, marker='d')
plt.title('Statistics Summary for collegeGPA')
plt.xlabel('Statistical Measures')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Job Period

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(df3['JobPeriod'])
plt.show()

# %%
df3.hist(column=["JobPeriod"], color='red', alpha=0.5, edgecolor='black', figsize = (10, 7))
plt.show()

# %%
df3['JobPeriod'].describe()[1:].plot(color = 'orange', marker = 'D', markersize = 7)
# plt.plot(df3.index, df3.Salary.describe(), markevery=1, marker='d')
plt.title('Statistics Summary for JobPeriod')
plt.xlabel('Statistical Measures')
plt.tight_layout()
plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# 1. Most of the students work experience is 3 years
# 2. Boxplot: Presence of outliers due to large tenure values
# 3. Histogram: The data is positively skewed i.e large number of employees have low tenure of 2.5 years

# %% [markdown]
# ##### Univariate Analysis - Categorical Columns

# %% [markdown]
# ##### Designation

# %%
plt.figure(figsize=(10, 5))
ax = df3['Designation'].value_counts().sort_values(ascending = True).plot(kind = 'bar',color = 'blue', edgecolor = 'black')
plt.title('Count of Students based on Designation', size = 15)
plt.yticks(size = 15)
plt.ylabel('Designation', size = 15)
plt.xlabel('Count', size = 15)
# plt.tight_layout()

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Top preferred designations by students are:
# 1. Engineer
# 2. Developer
# 3. Analyst

# %%
Top_10_Cities = df3['JobCity'].value_counts()[:10]
ax = Top_10_Cities.plot(kind='barh',figsize=(10,8), edgecolor='black', color='orange')
plt.title('Top 10 Job Cities', size = 15)
plt.ylabel('Job City', size = 15)
plt.xlabel('Count', size = 15)
# plt.tight_layout()

# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

for c in ax.containers:
    # set the bar label
    ax.bar_label(c, fmt='%.0f', label_type='edge')

# ax.legend(title='Job City', bbox_to_anchor=(1, 1.02), loc='upper left')

# ax.spines['right'].set_visible(False)
# ax.spines['top'].set_visible(False)

plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Top preferred Job City by students are:
# 1. Bangalore
# 2. Noida
# 3. Hyderabad
# 4. Pune

# %% [markdown]
# ##### Gender

# %%
df3.Gender.value_counts()
# Out:
# Male      3041
# Female     957
# Name: Gender, dtype: int64

# %%
# (df3.Gender.value_counts())
# df3.boxplot(column =df3.Gender.value_counts(), by = 'Gender', figsize = (10,7))
# plt.show()

# %%
plt.figure(figsize=(7, 5))
ax=sns.countplot(df3['Gender'], palette='cool_r', edgecolor ='black')
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.show()

# %%
plt.figure(figsize=(12,7))
explode = (0, 0.05)
plt.pie(df3.Gender.value_counts(), colors = ( "pink", "cyan"), explode = explode, shadow = True, labels = ['Male','Female'], autopct='%0.0f%%', textprops={'fontsize': 14})
plt.title('Student Distribution By Gender', fontsize=15, pad = 15)
plt.show()

# %% [markdown]
# *OBERVATION:**
#
# 1. The data is unbalanced in terms of gender.
# 2. More male population than female

# %%
df3.CollegeTier.value_counts()
# Out:
# 2    3701
# 1     297
# Name: CollegeTier, dtype: int64

# %%
plt.figure(figsize=(12,7))
explode = (0, 0.05)
plt.pie(df3.CollegeTier.value_counts(), colors = ( "orange", "yellow"), explode = explode, shadow = True, labels = ['2','1'], autopct='%0.0f%%', textprops={'fontsize': 14})
plt.title('Student Distribution By CollegeTier', fontsize=15, pad = 15)
plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Almost 93% student belongs to Tier 2 Colleges

# %%
Top_10_Cities = df3['CollegeState'].value_counts()[:15]
ax = Top_10_Cities.plot(kind='barh',figsize=(10,8), edgecolor='black', color='green')
plt.title('Top 10 College State', size = 15)
plt.ylabel('College State', size = 15)
plt.xlabel('Count', size = 15)
# plt.tight_layout()

# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

for c in ax.containers:
    # set the bar label
    ax.bar_label(c, fmt='%.0f', label_type='edge')

# ax.legend(title='Job City', bbox_to_anchor=(1, 1.02), loc='upper left')

# ax.spines['right'].set_visible(False)
# ax.spines['top'].set_visible(False)

plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Most of the students did their education in colleges belonging to following states:
# 1. Uttar Pradesh
# 2. Karnataka
# 3. Tamil Nadu
# 4. Telangana
# 5. Maharashtra

# %% [markdown]
# ##### Board

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(20,5))
fig.suptitle('Count of Student based on Board')
axes[0].set_title('Count of 12board')
axes[1].set_title('Count of 10board')

ax = sns.countplot(df3['12board'], ax=axes[0], palette='spring_r', edgecolor ='black')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

ax = sns.countplot(df3['10board'], ax=axes[1], palette='spring', edgecolor ='black')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))


axes[0].set_xlabel('12 Board')
axes[1].set_xlabel('10 Board')

plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Students prefer Stateboard followed by CBSE and ICSE for 10th and 12th education

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(20,5))
fig.suptitle('Count of Student based on Graduation')
axes[0].set_title('Count of 12graduation')
axes[1].set_title('Count of GraduationYear')

ax = sns.countplot(df3['12graduation'], ax=axes[0], palette='summer', edgecolor ='black')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

ax = sns.countplot(df3['GraduationYear'], ax=axes[1], palette='summer_r', edgecolor ='black')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))


axes[0].set_xlabel('12 Graduation')
axes[1].set_xlabel('Graduation Year')

plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# 1. Maximum students passout from 12th in the year: 2009, followed by 2008, 2010, 2007, 2006 years
#
# 2. Maximum students graduated in the year: 2013, 2014, 2012

# %% [markdown]
# ##### Degree

# %%
plt.figure(figsize=(12,7))
# fig.suptitle('Count of Student based on Board')
plt.title('Count of Student based on Degree')

ax = sns.countplot(df3['Degree'], palette='rainbow', edgecolor ='black')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

plt.xlabel('Degree')

plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Majority of students are B.Tech/B.E

# %% [markdown]
# ##### Specialization

# %%
plt.figure(figsize=(12,7))
# fig.suptitle('Count of Student based on Board')
plt.title('Count of Student based on Specialization')

ax = sns.countplot(df3['Specialization'], edgecolor ='black')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

plt.xlabel('Specialization')

plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Preferred Specialization are:
# 1. CS
# 2. EC
# 3. IT
# 4. ME

# %% [markdown]
# #### Outlier Treatment

# %%
def outlier_treatment(column_name):
    sorted(column_name)
    Q1,Q3 = np.percentile(column_name , [25,75])
    IQR = Q3 - Q1
    lower_range = Q1 - (1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range

# %%
df3.columns
# Out:
# Index(['ID', 'Salary', 'Designation', 'JobCity', 'Gender', '10percentage',
#        '10board', '12graduation', '12percentage', '12board', 'CollegeTier',
#        'Degree', 'Specialization', 'collegeGPA', 'CollegeCityID',
#        'CollegeCityTier', 'CollegeState', 'GraduationYear', 'Domain',
#        'JobPeriod', 'DOByear', '12GradAge', 'GradAge', 'Designation_Position',
#        'Personality Trait Score'],
#       dtype='object')

# %%
columns_numerical = ['Salary','10percentage','12percentage','collegeGPA','JobPeriod','GradAge','Personality Trait Score']
df3_no_outliers = df3.copy()

# %%
for cols in columns_numerical:
    #exctracting upperbound and lowerbound
    lowerbound,upperbound = outlier_treatment(df3_no_outliers[cols])

    #dropping the outlier
    df3_no_outliers = df3_no_outliers.drop(df3_no_outliers[(df3_no_outliers[cols] < lowerbound) | (df3_no_outliers[cols] > upperbound)].index)

# %%
print(f'Number of observations with outliers : {df3.shape[0]}')
print(f'Number of observations without outliers : {df3_no_outliers.shape[0]}')
# Out:
# Number of observations with outliers : 3998
# Number of observations without outliers : 3708

# %% [markdown]
# ##### Bivariate Analysis

# %% [markdown]
# ##### Salary Vs Designation

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15,5))
fig.suptitle('Salary Vs Designation')
axes[0].set_title('Salary Vs Designation')
axes[1].set_title('Salary Vs Designation Without Outliers')

ax = sns.barplot(data = df3, x='Designation', y='Salary', ax=axes[0], palette='spring', edgecolor ='black', ci=None)
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for i in ax.containers:
    ax.bar_label(i,)

# ax.set_xticklabels()

ax = sns.barplot(data = df3_no_outliers, x='Designation', y='Salary', ax=axes[1], palette='spring', edgecolor ='black', ci=None)
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for i in ax.containers:
    ax.bar_label(i,)


axes[0].set_xlabel('Designation')
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)
# plt.xticks(rotation=90)
# axes[0].set_xticks(90)
axes[1].set_xlabel('Designation')
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)
# plt.xticks(rotation=90)
# axes[1].set_xticks(90)

plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Designations with high Salary are:
# 1. Senior Positions
# 2. Manager
# 3. Engineer
# 4. Analyst

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15,5))
fig.suptitle('Salary Vs Specialization')
axes[0].set_title('Salary Vs Specialization')
axes[1].set_title('Salary Vs Specialization Without Outliers')

ax = sns.barplot(data = df3, x='Specialization', y='Salary', ax=axes[0], palette='coolwarm', edgecolor ='black', ci=None)
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for i in ax.containers:
    ax.bar_label(i,)

# ax.set_xticklabels()

ax = sns.barplot(data = df3_no_outliers, x='Specialization', y='Salary', ax=axes[1], palette='coolwarm', edgecolor ='black', ci=None)
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for i in ax.containers:
    ax.bar_label(i,)


axes[0].set_xlabel('Specialization')
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)
# plt.xticks(rotation=90)
# axes[0].set_xticks(90)
axes[1].set_xlabel('Specialization')
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)
# plt.xticks(rotation=90)
# axes[1].set_xticks(90)

plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Specializations with high Salary:
# 1. I&C
# 2. CE
# 3. CS
# 4. ME
# 5. IT
# 6. EC

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(20, 10))

# Load the example car crash dataset
# crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
ax = sns.barplot(x="Degree", y="Salary", data=df3,
            label="With Outlier", color="b", ci=None)
for i in ax.containers:
    ax.bar_label(i,)

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
ax=sns.barplot(x="Degree", y="Salary", data=df3_no_outliers,
            label="Without Outliers", color="b", ci=None)
for i in ax.containers:
    ax.bar_label(i,)

# Add a legend and informative axis label
ax.legend(ncol=2, loc="upper right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Salary Vs Degree")
sns.despine(left=True, bottom=True)

plt.xticks(rotation=90)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15,5))
fig.suptitle('Salary Vs Degree')
axes[0].set_title('Salary Vs Degree')
axes[1].set_title('Salary Vs Degree Without Outliers')

ax = sns.barplot(x=df3.Salary, y=df3.Degree, ax=axes[0], palette='coolwarm', edgecolor ='black', ci=None, orient = 'h')
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for i in ax.containers:
    ax.bar_label(i,)

# ax.set_xticklabels()

ax = sns.barplot(x=df3_no_outliers.Salary, y=df3_no_outliers.Degree, ax=axes[1], palette='coolwarm', edgecolor ='black', ci=None, orient='h')
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
for i in ax.containers:
    ax.bar_label(i,)


axes[0].set_xlabel('Degree')
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)
# plt.xticks(rotation=90)
# axes[0].set_xticks(90)
axes[1].set_xlabel('Degree')
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)
# plt.xticks(rotation=90)
# axes[1].set_xticks(90)

plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Education with high Salary:
# 1. M.Tech/M.E
# 2. B.Tech/B.E

# %% [markdown]
# ##### Salary Vs Gender

# %%
fig, axes = plt.subplots(1, 2, squeeze=False, sharey=True, figsize=(15, 10))
fig.suptitle('Salary Vs Gender')

axes[0, 0].set_title('Salary Vs Gender With Outliers')
axes[0, 1].set_title('Salary Vs Gender Without Outliers')

sns.boxplot(ax=axes[0, 0], data=df3, x='Gender', y='Salary')
sns.boxplot(ax=axes[0, 1], data=df3_no_outliers, x='Gender', y='Salary')

plt.show()

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15,5))
fig.suptitle('Salary Vs Gender')
axes[0].set_title('Salary Vs Gender')
axes[1].set_title('Salary Vs Gender Without Outliers')

ax = sns.barplot(x=df3.Salary, y=df3.Gender, ax=axes[0], palette='Blues_r', edgecolor ='black', ci=None, orient = 'h')
for i in ax.containers:
    ax.bar_label(i,)


ax = sns.barplot(x=df3_no_outliers.Salary, y=df3_no_outliers.Gender, ax=axes[1], palette='Blues_r', edgecolor ='black', ci=None, orient='h')
for i in ax.containers:
    ax.bar_label(i,)


axes[0].set_xlabel('Gender')
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

axes[1].set_xlabel('Gender')
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)


plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# Gender with high Salary: Male have high Salary than Female

# %%
plt.figure(figsize=(10,5))
ax=sns.barplot(x=df3['JobPeriod'], y=df3['Salary'], ci=None)
for i in ax.containers:
    ax.bar_label(i,)

plt.xticks(fontsize=12)
plt.title("Experience Vs Salary", fontsize=18, color='black');
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.barplot(x=df3_no_outliers['JobPeriod'], y=df3_no_outliers['Salary'], ci=None)
for i in ax.containers:
    ax.bar_label(i,)

plt.xticks(fontsize=12)
plt.title("Experience Vs Salary", fontsize=18, color='black');
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.regplot(x=df3_no_outliers['JobPeriod'], y=df3_no_outliers['Salary'],marker='*', 
            color='orange', line_kws=dict(color='black'))
plt.xticks(fontsize=12)
plt.title("Relationship between Years of Experience and Salary", fontsize=18, color='blue');

# %%
# Creating crosstab
crosstb = pd.crosstab(df3.Degree, df3.Gender)
crosstb
 
# Creating barplot
# pl = crosstb.plot(kind="bar", stacked=True, rot=0)
# Out:
# Gender         Female  Male
# Degree
# B.Tech/B.E.       889  2811
# M.Sc. (Tech.)       1     1
# M.Tech./M.E.        9    44
# MCA                58   185

# %% [markdown]
# **OBSERVATION:**
#
# Education Vs Gender:
# More number of Male have graduate and post-graduate degree than Female

# %%
barplot = crosstb.plot.bar(rot=0)
for i in barplot.containers:
    barplot.bar_label(i,)

# %% [markdown]
# **Research Questions:**
#
# Times of India article dated Jan 18, 2019 states that “After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh graduate.”
# Test this claim with the data given to you.

# %%
df3[df3['Specialization']=='CS'].value_counts().sum()
# Out:
# 1599

# %%
# df2[df2['Designation_Position']=='Analyst'].value_counts().sum()

# %%
designation_position_list=df3[(df3['Designation_Position']=='Program Analyst Trainee') | 
           (df3['Designation_Position']=='Programmer Analyst Trainee') |
           (df3['Designation_Position']=='Software Engineer') | 
           (df3['Designation_Position']=='Hardware Engineer and Associate Engineer') |
           (df3['Designation_Position']=='Associate Software Engineer') |
           (df3['Designation_Position']=='Software Programmer') |
           (df3['Designation_Position']=='Software Engineer Trainee') |
           (df3['Designation_Position']=='Software Trainee') |
           (df3['Designation_Position']=='Associate Software Engineer') |
           (df3['Designation_Position']=='Hardware Engineer')]
designation_position_list.head(1)
# Out:
#         ID  Salary Designation JobCity  Gender  10percentage 10board  \
# 19  466888  325000    Engineer    Pune  Female          79.0    CBSE
#
#     12graduation  12percentage 12board  CollegeTier       Degree  \
# 19          2008          62.2    CBSE            2  B.Tech/B.E.
#
#    Specialization  collegeGPA  CollegeCityID  CollegeCityTier   CollegeState  \
# 19             CS        76.3           7977                0  Uttar Pradesh
#
#     GraduationYear    Domain  JobPeriod  DOByear  12GradAge  GradAge  \
# 19            2012  0.864685          9     1990         18       22
#
#    Designation_Position  Personality Trait Score
# 19    Software Engineer                  0.05546

# %%
designation_position_list.shape[0]
# Out:
# 621

# %%
a=designation_position_list.groupby('Designation_Position').Salary.mean().sort_values(ascending=False)
a
# Out:
# Designation_Position
# Software Engineer Trainee      610000.000000
# Software Engineer              340562.730627
# Software Programmer            330000.000000
# Program Analyst Trainee        325000.000000
# Programmer Analyst Trainee     312000.000000
# Associate Software Engineer    310480.769231
# Hardware Engineer              281250.000000
# Software Trainee               129285.714286
# Name: Salary, dtype: float64

# %%
plt.figure(figsize=(10,5))
ax=sns.barplot(x=designation_position_list.Designation_Position , y=designation_position_list.Salary, order=designation_position_list.groupby('Designation_Position').Salary.mean().sort_values(ascending=False).index[:60],ci=None)
for i in ax.containers:
    ax.bar_label(i,)
plt.title('Salary Vs Designation Position')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **OBSERVATION:**
#
# “After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate
#
# Engineer you can earn up to 2.5-3 lakhs as a fresh graduate.”
# This test claim with the data given is False.

# %% [markdown]
# **Research Questions:**
#
# Is there a relationship between gender and specialisation? (i.e. Does the preference of Specialisation depend on the Gender?)

# %%
crosstb_1 = pd.crosstab(df3.Specialization, df3.Gender)
crosstb_1
# Out:
# Gender          Female  Male
# Specialization
# AE                   1     2
# BM                   2     0
# BT                   9     6
# CE                   6    23
# CS                 420  1179
# EC                 312  1069
# I&C                  9    11
# IN                   0     4
# IT                 183   506
# ME                  11   206
# Other                4    35

# %%
# crosstb_2 = pd.crosstab(df3.Gender, df3.Specialization)
# crosstb_2

# %%
# plt.figure(figsize=(20, 10))
barplot = crosstb_1.plot.bar(rot=0, figsize=(10, 5))
for i in barplot.containers:
    barplot.bar_label(i,)

# %% [markdown]
# **OBSERVATION:**
#
# 1. Both Male Female prefer CS, EC and IT as specialization
# 2. Number of Male are more in CS, EC and IT than Female

# %%
crosstb = pd.crosstab(df3.Degree, df3.Specialization)
crosstb
# Out:
# Specialization  AE  BM  BT  CE    CS    EC  I&C  IN   IT   ME  Other
# Degree
# B.Tech/B.E.      3   2  15  29  1328  1370   18   4  684  215     32
# M.Sc. (Tech.)    0   0   0   0     2     0    0   0    0    0      0
# M.Tech./M.E.     0   0   0   0    26    11    2   0    5    2      7
# MCA              0   0   0   0   243     0    0   0    0    0      0

# %%
table_df3 = pd.pivot_table(data=df3, index='Gender', values=['collegeGPA', '12percentage', '10percentage'], aggfunc = 'mean')
table_df3
# Out:
#         10percentage  12percentage  collegeGPA
# Gender
# Female     80.932894     77.007618   74.048056
# Male       76.979000     73.666636   70.679947

# %%
table_df3_no_outliers = pd.pivot_table(data=df3_no_outliers, index='Gender', values=['collegeGPA', '12percentage', '10percentage'], aggfunc = 'mean')
table_df3_no_outliers
# Out:
#         10percentage  12percentage  collegeGPA
# Gender
# Female     80.996858     77.104513   73.888783
# Male       77.308295     73.902985   70.834248

# %% [markdown]
# **OBSERVATION:**
#
# Female students have performed better in 10th, 12th and college GPA than Male students

# %%
table_df3_1 = pd.pivot_table(data=df3, index=['Gender', 'Degree'], values=['Salary', 'collegeGPA'], aggfunc = 'mean')
table_df3_1
# Out:
#                              Salary  collegeGPA
# Gender Degree
# Female B.Tech/B.E.    294713.160855   73.783723
#        M.Sc. (Tech.)  180000.000000   70.000000
#        M.Tech./M.E.   511666.666667   86.303333
#        MCA            266724.137931   76.267759
# Male   B.Tech/B.E.    313021.700462   70.493152
#        M.Sc. (Tech.)  460000.000000   81.200000
#        M.Tech./M.E.   336363.636364   73.091136
#        MCA            285216.216216   72.887892

# %%
table_df3_no_outliers_1 = pd.pivot_table(data=df3_no_outliers, index=['Gender', 'Degree'], values=['Salary', 'collegeGPA'], aggfunc = 'mean')
table_df3_no_outliers_1
# Out:
#                              Salary  collegeGPA
# Gender Degree
# Female B.Tech/B.E.    279072.104019   73.707719
#        M.Sc. (Tech.)  180000.000000   70.000000
#        M.Tech./M.E.   353750.000000   83.550000
#        MCA            249811.320755   76.123208
# Male   B.Tech/B.E.    292119.494447   70.631766
#        M.Tech./M.E.   287567.567568   76.988108
#        MCA            245993.589744   72.763654

# %%
table_df3_2 = pd.pivot_table(data=df3, index=['Gender', 'Specialization'], values=['Salary'], aggfunc = 'mean')
table_df3_2
# Out:
#                               Salary
# Gender Specialization
# Female AE              180000.000000
#        BM              290000.000000
#        BT              247222.222222
#        CE              315000.000000
#        CS              306845.238095
#        EC              280064.102564
#        I&C             384444.444444
#        IT              288469.945355
#        ME              322272.727273
#        Other           332500.000000
# Male   AE              132500.000000
#        BT              265000.000000
#        CE              398478.260870
#        CS              316891.433418
#        EC              301580.916745
#        I&C             401818.181818
#        IN              240000.000000
#        IT              314328.063241
#        ME              312592.233010
#        Other           345142.857143

# %%
table_df3_no_outliers_2 = pd.pivot_table(data=df3_no_outliers, index=['Gender', 'Specialization'], values=['Salary'], aggfunc = 'mean')
table_df3_no_outliers_2
# Out:
#                               Salary
# Gender Specialization
# Female AE              180000.000000
#        BM              290000.000000
#        BT              247222.222222
#        CE              238000.000000
#        CS              280658.914729
#        EC              266661.129568
#        I&C             342500.000000
#        IT              286843.575419
#        ME              322272.727273
#        Other           310000.000000
# Male   AE              132500.000000
#        BT              278000.000000
#        CE              329722.222222
#        CS              291096.774194
#        EC              285626.252505
#        I&C             312000.000000
#        IN              240000.000000
#        IT              298646.055437
#        ME              273730.769231
#        Other           299677.419355

# %%
table_df3_3 = pd.pivot_table(data=df3, index=['Gender', 'Designation'], values=['Salary'], aggfunc = 'mean')
table_df3_3
# Out:
#                            Salary
# Gender Designation
# Female Analyst      279708.333333
#        Associate    327826.086957
#        Consultant   200714.285714
#        Designer     170555.555556
#        Developer    253023.952096
#        Engineer     323333.333333
#        Executive    179722.222222
#        Manager      306521.739130
#        Others       284726.027397
#        Senior       456500.000000
#        Trainee      251363.636364
# Male   Analyst      331861.702128
#        Associate    222976.190476
#        Consultant   348333.333333
#        Designer     214642.857143
#        Developer    251217.564870
#        Engineer     318507.210031
#        Executive    197045.454545
#        Manager      422600.000000
#        Others       340766.129032
#        Senior       502424.242424
#        Trainee      209565.217391

# %%
table_df3_no_outliers_3 = pd.pivot_table(data=df3_no_outliers, index=['Gender', 'Designation'], values=['Salary'], aggfunc = 'mean')
table_df3_no_outliers_3
# Out:
#                            Salary
# Gender Designation
# Female Analyst      277391.304348
#        Associate    264761.904762
#        Consultant   200714.285714
#        Designer     170555.555556
#        Developer    240095.541401
#        Engineer     302960.199005
#        Executive    179722.222222
#        Manager      253571.428571
#        Others       272058.823529
#        Senior       350625.000000
#        Trainee      268000.000000
# Male   Analyst      313897.338403
#        Associate    222976.190476
#        Consultant   348333.333333
#        Designer     165909.090909
#        Developer    239934.782609
#        Engineer     301438.420348
#        Executive    199250.000000
#        Manager      361117.647059
#        Others       284476.923077
#        Senior       449642.857143
#        Trainee      213295.454545

# %% [markdown]
# ##### Correlation Plot

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df3.corr(), annot = True, cmap = 'YlGnBu')
plt.show()
